# %%
import pandas as pd

# %%
df = pd.read_csv("data/orders.csv")

print(df)
# Out:
#     Номер заказа             Клиент        Дата     Сумма
# 0           1001        Алиев Рашад  2024-01-03  12500.00
# 1           1002    Мамедова Гюнель  2024-01-05   8750.50
# 2           1003     Гасанов Эльчин  2024-01-08  23400.00
# 3           1004  Исмайлова Нилуфар  2024-01-11   5600.75
# 4           1005     Керимов Тогрул  2024-01-15  17800.00
# 5           1006      Алиева Самира  2024-01-18   9320.25
# 6           1007     Гусейнов Орхан  2024-01-22  31200.00
# 7           1008   Мустафаева Лейла  2024-01-25   6450.00
# 8           1009      Бабаев Фикрет  2024-01-28  14900.50
# 9           1010    Зейналова Айнур  2024-02-01  22100.00
# 10          1011        Алиев Рашад  2024-02-04   9800.00
# 11          1012     Гасанов Эльчин  2024-02-07  15300.75
# 12          1013     Керимов Тогрул  2024-02-10  42000.00
# 13          1014    Мамедова Гюнель  2024-02-13   7650.00
# 14          1015       Рзаев Камран  2024-02-16  19500.00
# ...

# %%
# Выведите первые десять строк.

first_10 = df.head(10)
print(first_10)
# Out:
#    Номер заказа             Клиент        Дата     Сумма
# 0          1001        Алиев Рашад  2024-01-03  12500.00
# 1          1002    Мамедова Гюнель  2024-01-05   8750.50
# 2          1003     Гасанов Эльчин  2024-01-08  23400.00
# 3          1004  Исмайлова Нилуфар  2024-01-11   5600.75
# 4          1005     Керимов Тогрул  2024-01-15  17800.00
# 5          1006      Алиева Самира  2024-01-18   9320.25
# 6          1007     Гусейнов Орхан  2024-01-22  31200.00
# 7          1008   Мустафаева Лейла  2024-01-25   6450.00
# 8          1009      Бабаев Фикрет  2024-01-28  14900.50
# 9          1010    Зейналова Айнур  2024-02-01  22100.00
